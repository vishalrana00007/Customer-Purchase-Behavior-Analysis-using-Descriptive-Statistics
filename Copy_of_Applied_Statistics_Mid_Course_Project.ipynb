# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalrana00007/Customer-Purchase-Behavior-Analysis-using-Descriptive-Statistics/blob/main/Copy_of_Applied_Statistics_Mid_Course_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍

# %% [markdown]
# # **Importing dataset and libraries**

# %%
# Importing Libraries
from warnings import filterwarnings as w
w('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk
from wordcloud import WordCloud, STOPWORDS
import plotly.express as px
import matplotlib.image as mpimg
import plotly.io as pio

# %%
# Loading Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_location = '/content/drive/MyDrive/Superstore Marketing Data - Sheet1.csv'
sm_df = pd.read_csv(file_location, encoding = 'ISO-8859-1')
sm_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
sm_df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
sm_df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# # **Inspecting Dataframe**

# %%
num_rows, num_columns = sm_df.shape

print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 2240
# Number of columns: 22

# %%
# Dataset Info
sm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
duplicate_count = sm_df.duplicated().sum()

print("Number of duplicate values:", duplicate_count)
# Out:
# Number of duplicate values: 0

# %% [markdown]
# **Checking null values**

# %%
# Missing Values/Null Values Count
missing_values_count = sm_df.isnull().sum()

print(missing_values_count)
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
sm_df.dropna(subset=['Income'], inplace=True)

# %%
missing_values_count = sm_df.isnull().sum()

print(missing_values_count)
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
from datetime import datetime

# Getting the current year
current_year = datetime.now().year

# Creating the 'Age' column by subtracting the 'Year_Birth' from the current year
sm_df['Age'] = current_year - sm_df['Year_Birth']

# Updated DataFrame with 'Age' column
sm_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntSweetProducts  \
# ...

# %% [markdown]
# # **Checking corelation between the attributes**

# %%
numeric_columns = sm_df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(18,12))
sns.heatmap(numeric_columns.corr(), annot=True)
plt.show()

# %% [markdown]
# # **Descriptive data analysis**

# %%
# Descriptive statistics
demographics = sm_df[['Age', 'Education', 'Marital_Status']]
demo_descriptive_stats = demographics.describe()

# Displaying the descriptive statistics
print(demo_descriptive_stats)

# Visualization
plt.figure(figsize=(15, 5))

# Age distribution
plt.subplot(1, 3, 1)
sns.histplot(sm_df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.ylabel('Number of customers')

# Education level distribution
plt.subplot(1, 3, 2)
sns.countplot(data=sm_df, x='Education')
plt.title('Education Level Distribution')
plt.ylabel('Number of customers')

# Marital status distribution
plt.subplot(1, 3, 3)
sns.countplot(data=sm_df, x='Marital_Status')
plt.title('Marital Status Distribution')
plt.ylabel('Number of customers')

plt.tight_layout()
plt.show()
# Out:
#                Age
# count  2216.000000
# mean     55.179603
# std      11.985554
# min      28.000000
# 25%      47.000000
# 50%      54.000000
# 75%      65.000000
# max     131.000000

# %% [markdown]
# **Conclusion**:
#
# A Clear View of Our Customers :-
# Examining the charts, we see a significant concentration of customers within the 45-65 age range. Educational attainment leans towards graduates, with a notable presence of PhD and Master's degree holders. Marital status skews towards married couples, followed by those in live-in partnerships, singles, and divorced individuals.
#
# Leveraging Customer Insights for Growth:-
# This valuable demographic data presents a powerful opportunity to enhance sales strategies. By understanding our core customer base, we can tailor messaging, product offerings, and marketing campaigns to resonate more effectively with their specific needs and preferences. Imagine targeted campaigns that cater to the interests of well-educated, established individuals in the 45-65 age group.

# %%
# Selecting the  key variables to analyze:
key_variables = ['Year_Birth', 'Income', 'MntWines']

# Descriptive statistics:
central_tendency = sm_df[key_variables].agg(['mean', 'median', lambda x: x.mode().values[0]])
dispersion = sm_df[key_variables].agg(['var', 'std'])

# Handle outliers (example for 'Income' variable):
Q1 = sm_df['Income'].quantile(0.25)
Q3 = sm_df['Income'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

sm_df = sm_df[(sm_df['Income'] >= lower_bound) & (sm_df['Income'] <= upper_bound)]

# Visualizing outliers for Income
plt.figure(figsize=(8, 5))
sns.boxplot(x=sm_df['Income'])
plt.title('Boxplot of Income')
plt.show()

# Display descriptive statistics
print("Measures of Central Tendency:")
print(central_tendency)

print("\nMeasures of Dispersion:")
print(dispersion)
# Out:
# Measures of Central Tendency:
#            Year_Birth        Income    MntWines
# mean      1968.820397  52247.251354  305.091606
# median    1970.000000  51381.500000  174.500000
# <lambda>  1976.000000   7500.000000    2.000000
#
# Measures of Dispersion:
#      Year_Birth        Income      MntWines
# var  143.653507  6.336838e+08  113790.12569
# std   11.985554  2.517308e+04     337.32792

# %% [markdown]
# **Conclusion**:
# Examining the income distribution in the boxplot, we observe that a significant portion of customers falls within the 35K to 65K bracket. This valuable customer insight presents a strategic opportunity to boost sales through targeted campaigns that leverage discounts or other promotional strategies tailored to this income range.

# %%
from scipy import stats

# Calculating basic statistics for numerical variables
numerical_vars = [ 'MntFishProducts',
                  'MntMeatProducts', 'MntFruits', 'MntSweetProducts',
                  'MntWines', 'MntGoldProds', 'NumDealsPurchases',
                  'NumCatalogPurchases', 'NumStorePurchases',
                  'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']

for var in numerical_vars:
  print(f"Variable: {var}")
  # Descriptive statistics
  print(sm_df[var].describe())

  # Checking for normality
  try:
    # Shapiro-Wilk test for normality
    stat, pval = stats.shapiro(sm_df[var])
    if pval > 0.05:
      print(f"{var} distribution might be normal (p-value: {pval:.2f})")
    else:
      print(f"{var} distribution might not be normal (p-value: {pval:.2f})")
  except:
    pass  # Handling potential errors for non-numeric data

# Analyzing Response (target) - Binomial distribution (potentially)
response_rate = sm_df['Response'].mean()
print(f"\nResponse (target): Binomial distribution (success rate: {response_rate:.2f})")

# Analyzing Complain - Binomial distribution (potentially)
complaint_rate = sm_df['Complain'].mean()
print(f"\nComplain: Binomial distribution (complaint rate in last 2 years: {complaint_rate:.2f})")
# Out:
# Variable: MntFishProducts
# count    2208.000000
# mean       37.758605
# std        54.813323
# min         0.000000
# 25%         3.000000
# 50%        12.000000
# 75%        50.000000
# max       259.000000
# Name: MntFishProducts, dtype: float64
# MntFishProducts distribution might not be normal (p-value: 0.00)
# Variable: MntMeatProducts
# count    2208.000000
# mean      165.347826
# std       217.852649
# min         0.000000
# 25%        16.000000
# 50%        68.000000
# 75%       232.000000
# max      1725.000000
# Name: MntMeatProducts, dtype: float64
# MntMeatProducts distribution might not be normal (p-value: 0.00)
# Variable: MntFruits
# count    2208.000000
# mean       26.435236
# std        39.842478
# min         0.000000
# 25%         2.000000
# 50%         8.000000
# 75%        33.000000
# max       199.000000
# Name: MntFruits, dtype: float64
# MntFruits distribution might not be normal (p-value: 0.00)
# Variable: MntSweetProducts
# count    2208.000000
# ...

# %% [markdown]
# **Conclusion:**
# This summary provides a comprehensive overview of customer spending habits across various categories. We can analyze key metrics like count, mean, standard deviation, minimum, various percentiles (25th, 50th, and 75th), and maximum values for purchases in fish, meat, fruits, sweets, wines, gold products, and explore details like online and offline purchase frequencies (number of deals, catalog, store, and web purchases), website visits per month, and recency of purchases. These insights offer invaluable guidance in understanding customer purchasing dynamics, enabling the company to tailor strategies for optimized sales performance.

# %%
import scipy.stats as stats

# Selecting variables to analyze
selected_variables = ['NumStorePurchases', 'NumWebPurchases', 'Income']

# Checking normality assumption for selected variables using Shapiro-Wilk test
for var in selected_variables:
    stat, p = stats.shapiro(sm_df[var])
    print(f'{var} Shapiro-Wilk test p-value: {p}')

# Identifying variables that could follow specific distributions
# Example: If p-value is not significant for Normality assumption, 'NumStorePurchases' might follow a Poisson distribution

# Calculating probabilities and expected values based on the identified distribution (e.g., Poisson)
lambda_val = sm_df['NumStorePurchases'].mean()  # Expected value for Poisson distribution

# Calculating probabilities for Poisson distribution
poisson_probabilities = [stats.poisson.pmf(k, lambda_val) for k in range(0, 10)]  # Probabilities for 0 to 9 purchases

# Display probabilities for Poisson distribution
for k, prob in enumerate(poisson_probabilities):
    print(f'P(X = {k}) = {prob}')
# Out:
# NumStorePurchases Shapiro-Wilk test p-value: 1.5206371131595364e-35
# NumWebPurchases Shapiro-Wilk test p-value: 1.1929301233284735e-34
# Income Shapiro-Wilk test p-value: 8.723606723332143e-15
# P(X = 0) = 0.002969702563177488
# P(X = 1) = 0.01728157075827334
# P(X = 2) = 0.050283266003861904
# P(X = 3) = 0.09753769397397673
# P(X = 4) = 0.14190011660684176
# P(X = 5) = 0.16515168462693025
# P(X = 6) = 0.16017768687888187
# P(X = 7) = 0.13316013837388396
# P(X = 8) = 0.09686224060043228
# P(X = 9) = 0.06262997833509243

# %%
import scipy.stats as stats

# Calculating mean and standard deviation for Age and Income
mean_age = sm_df['Age'].mean()
std_dev_age = sm_df['Age'].std()
mean_income = sm_df['Income'].mean()
std_dev_income = sm_df['Income'].std()

# Plotting histogram and comparing with normal distribution
plt.figure(figsize=(12, 6))

# Plotting histogram for Age
plt.subplot(1, 2, 1)
sns.histplot(sm_df['Age'], kde=True, bins=20, color='skyblue', stat='density')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mean_age, std_dev_age)
plt.plot(x, p, 'k', linewidth=2)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Density')

# Plotting histogram for Income
plt.subplot(1, 2, 2)
sns.histplot(sm_df['Income'], kde=True, bins=20, color='lightcoral', stat='density')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mean_income, std_dev_income)
plt.plot(x, p, 'k', linewidth=2)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Plotting the acceptance rate distribution across different Marital statuses
plt.figure(figsize=(8, 6))
sns.countplot(x='Marital_Status', hue='Response', data=sm_df, palette='pastel')
plt.title('Acceptance Rate across Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Response', labels=['Not Accepted', 'Accepted'])
plt.show()

# %% [markdown]
# **Conclusion:**
# Analyzing customer response to the company's offer by marital status reveals interesting trends. Singles, divorced, and widowed individuals exhibit a higher acceptance rate compared to married couples and those in live-in partnerships.

# %%
# Visualizing spending on different products
products = ['MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds']
product_names = ['Fish Products', 'Meat Products', 'Fruits', 'Sweet Products', 'Wines', 'Gold Products']
plt.figure(figsize=(12, 6))
sns.boxplot(data=sm_df[products], orient='h', palette='Set2')
plt.title('Spending Distribution on Different Product Categories')
plt.yticks(range(len(products)), product_names)
plt.xlabel('Amount Spent')
plt.ylabel('Product Category')
plt.show()

# %% [markdown]
# **Conclusion:** The boxplot reveals a fascinating trend in customer spending habits. Wine emerges as the category with the highest median expenditure, followed by meat products, fish products, and gold products. Notably, spending on fruits and sweet products falls at the lower end of the spectrum. This valuable customer insight presents a strategic opportunity for the company to identify areas for sales growth. By focusing efforts on promoting categories like fruits and sweet products, the company can unlock new revenue streams and cater to a wider range of customer preferences.

# %% [markdown]
# **Removing outliers**

# %%
sm_df = sm_df.apply(pd.to_numeric, errors='coerce')

# Now perform the outlier removal
q3 = sm_df.quantile(0.75)
q1 = sm_df.quantile(0.25)
iqr = q3 - q1
lower_range = q1 - (1.5 * iqr)
upper_range = q3 + (1.5 * iqr)

sm_df = sm_df[~((sm_df < lower_range) | (sm_df > upper_range)).any(axis=1)]

# %% [markdown]
# # **Binary Variables (Bernoulli Probability Distribution):**

# %%
# Calculating the proportion (probability) of customers who accepted the offer (1s)
accepted_offers_proportion = sm_df["Response"].mean()

# Printing the estimated proportion
print(f"Estimated Proportion of Customers who Accepted the Offer (p): {accepted_offers_proportion}")

# Plotting the probability mass function (PMF) for the Bernoulli distribution
plt.bar([0, 1], [1-accepted_offers_proportion, accepted_offers_proportion], tick_label=["Rejected (0)", "Accepted (1)"])
plt.title('Bernoulli Distribution of Offer Acceptance')
plt.xlabel('Offer Acceptance')
plt.ylabel('Probability')
plt.show()
# Out:
# Estimated Proportion of Customers who Accepted the Offer (p): 0.15027075812274368

# %%
# Calculating the proportion (probability) of customers who complained (1s)
complaints_proportion = sm_df["Complain"].mean()

# Plotting the probability mass function (PMF) for the Bernoulli distribution
plt.bar([0, 1], [1-complaints_proportion, complaints_proportion], tick_label=["No Complaint (0)", "Complaint (1)"])
plt.title('Bernoulli Distribution of Customer Complaints')
plt.xlabel('Complaint Status')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# **Conclusion:** Analyzing offer acceptance through a Bernoulli distribution reveals a high probability of rejection. Conversely, the Bernoulli distribution of customer complaints suggests a very low likelihood of complaints arising. These insights are valuable for the company to prioritize areas for improvement and ultimately boost sales.

# %% [markdown]
# # **Discrete Variables (Binomial or Poisson Probability Distribution):**

# %%
# Calculating the value counts for the number of deals purchases
num_deals_counts = sm_df['NumDealsPurchases'].value_counts().sort_index()

# Plotting the probability mass function (PMF) for the NumDealsPurchases
plt.bar(num_deals_counts.index, num_deals_counts / num_deals_counts.sum())
plt.title('Probability Mass Function of Number of Deals Purchases')
plt.xlabel('Number of Deals Purchases')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# **Conclusion:** Analyzing customer deal purchase frequency reveals a valuable pattern. We observe that a significant portion, approximately 40%, makes single deal purchases. This is followed by a gradual decrease in the frequency of repeat purchases, with 27% buying twice, 17% thrice, and so on. These insights present a strategic opportunity for the company to enhance sales.

# %%
# Calculating the value counts for the number of catalog purchases
num_catalog_counts = sm_df['NumCatalogPurchases'].value_counts().sort_index()

# Plotting the probability mass function (PMF) for the NumCatalogPurchases
plt.bar(num_catalog_counts.index, num_catalog_counts / num_catalog_counts.sum())
plt.title('Probability Mass Function of Number of Catalog Purchases')
plt.xlabel('Number of Catalog Purchases')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# **Conclusion:** Examining the chart, we discover a compelling trend in catalog purchase behavior. A substantial portion of customers, roughly 40%, not likely to make any catalog purchases . This is followed by a decreasing frequency of repeat purchases, with approximately 30% buying once, 13% buying twice, and so on. Interestingly, the probability of making eight purchases surpasses that of seven purchases. This valuable customer insight presents the company with a strategic opportunity to boost sales.

# %%
# Calculating the value counts for the number of store purchases
num_store_counts = sm_df['NumStorePurchases'].value_counts().sort_index()

# Plotting the probability mass function (PMF) for the NumStorePurchases
plt.bar(num_store_counts.index, num_store_counts / num_store_counts.sum())
plt.title('Probability Mass Function of Number of Store Purchases')
plt.xlabel('Number of Store Purchases')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# **Conclusion:** Analyzing the chart reveals a fascinating trend in store purchase frequency. Interestingly, customers are most likely to make store purchases three times, followed by four and then two times. The frequency steadily declines thereafter, with a surprising anomaly: the probability of making ten store purchases is higher than nine, and the same holds true for twelve purchases compared to eleven. These insights offer valuable strategic guidance for the company in optimizing store locations and numbers.

# %%
# Calculating the value counts for the number of web purchases
num_web_counts = sm_df['NumWebPurchases'].value_counts().sort_index()

# Plotting the probability mass function (PMF) for the NumWebPurchases
plt.bar(num_web_counts.index, num_web_counts / num_web_counts.sum())
plt.title('Probability Mass Function of Number of Web Purchases')
plt.xlabel('Number of Web Purchases')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# **Conclusion:** Customer web purchase behavior becomes clear when examining the chart. We observe that a significant portion of customers, approximately [percentage] (likely around 3%), haven't made any online purchases yet. Interestingly, the most frequent online purchase behavior involves making a single purchase. The likelihood of repeat purchases then steadily declines. This valuable customer insight offers the company an opportunity to develop targeted strategies to encourage online purchases and optimize their online sales channel.

# %% [markdown]
# # **Continuous Variables (Normal Probability Distribution):**

# %%
from scipy.stats import norm

# Calculating mean and standard deviation for Recency
mean_recency = sm_df["Recency"].mean()
std_dev_recency = sm_df["Recency"].std()

     # Printing the estimated mean and standard deviation
print(f"Estimated Mean Recency: {mean_recency}")
print(f"Estimated Standard Deviation of Recency: {std_dev_recency}")

     # Generating some data points for the x-axis
x_recency = np.linspace(mean_recency - 3*std_dev_recency, mean_recency + 3*std_dev_recency, 100)

     # Calculating the corresponding y-axis values using the normal distribution
y_recency = norm.pdf(x_recency, mean_recency, std_dev_recency)

# Plotting the probability distribution curves
plt.plot(x_recency, y_recency, label='Normal Distribution')
plt.title('Probability Distribution of Recency')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean Recency: 49.01263537906137
# Estimated Standard Deviation of Recency: 28.948351658624986

# %% [markdown]
# **Conclusion:** Examining the normal probability distribution of recency reveals a key insight: purchase frequency peaks at around 50 days. This valuable customer behavior data presents the company with a strategic opportunity to optimize their sales strategies. By understanding this timeframe, the company can develop targeted campaigns or incentives to encourage more frequent purchases and potentially shorten the repurchase cycle.

# %%
# Calculating mean and standard deviation for NumWebVisitsMonth
mean_visits = sm_df["NumWebVisitsMonth"].mean()
std_dev_visits = sm_df["NumWebVisitsMonth"].std()

# Printing the estimated mean and standard deviation
print(f"Estimated Mean Number of Web Visits: {mean_visits}")
print(f"Estimated Standard Deviation of Web Visits: {std_dev_visits}")

# Generating some data points for the x-axis
x_visits = np.linspace(mean_visits - 3*std_dev_visits, mean_visits + 3*std_dev_visits, 100)

# Calculating the corresponding y-axis values using the normal distribution
y_visits = norm.pdf(x_visits, mean_visits, std_dev_visits)

# Ploting the probability distribution curve
plt.plot(x_visits, y_visits, label='Normal Distribution')
plt.title('Probability Distribution of Number of Web Visits')
plt.xlabel('Number of Web Visits')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean Number of Web Visits: 5.847305389221557
# Estimated Standard Deviation of Web Visits: 1.9234118989142166

# %% [markdown]
# **Conclusion**: The normal probability distribution of website visits unveils an interesting trend: customers are most likely to visit the website six times a month. This valuable insight regarding online engagement presents the company with an opportunity to prioritize its online presence strategically.

# %%
from scipy.stats import norm

# Extracting the mean and standard deviation for the selected spending category
mean = sm_df['MntFishProducts'].mean()
std_dev = sm_df['MntFishProducts'].std()

print(f"Estimated Mean of Fish products: {mean}")
print(f"Estimated Standard Deviation of fish products: {std_dev}")
# Generating some data points for the x-axis
x = np.linspace(mean - 3*std_dev, mean + 3*std_dev, 100)

# Calculating the corresponding y-axis values using the normal distribution
y = norm.pdf(x, mean, std_dev)

# Plotting the continuous normal distribution
plt.plot(x, y, label='Normal Distribution')
plt.title(f'Continuous Normal Distribution of Fish Products')
plt.xlabel('Spending Amount')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean of Fish products: 37.63763537906137
# Estimated Standard Deviation of fish products: 54.75208241485161

# %% [markdown]
# **Conclusion:** The normal distribution of fish product spending offers valuable insights. Customers likely to spend around 40 unit money on fish products. This information empowers the company to develop strategic initiatives to boost fish product sales.

# %%
from scipy.stats import norm

# Extracting the mean and standard deviation for the "MntMeatProducts" variable
mean_meat = sm_df["MntMeatProducts"].mean()
std_dev_meat = sm_df["MntMeatProducts"].std()

print(f"Estimated Mean of Meat products: {mean_meat}")
print(f"Estimated Standard Deviation of Meat products: {std_dev_meat}")

# Generating some data points for the x-axis
x = np.linspace(mean_meat - 3*std_dev_meat, mean_meat + 3*std_dev_meat, 100)

# Calculating the corresponding y-axis values using the normal distribution
y = norm.pdf(x, mean_meat, std_dev_meat)

# Plotting the continuous normal distribution
plt.plot(x, y, label='Normal Distribution')
plt.title('Continuous Normal Distribution of MeatProducts')
plt.xlabel('Amount Spent on Meat Products')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean of Meat products: 166.99593862815885
# Estimated Standard Deviation of Meat products: 224.2832727589816

# %% [markdown]
# **Conclusion**: Analyzing the normal distribution of meat product spending reveals a positive trend. Customers tend to spend around 170 unit money on meat products, indicating strong sales performance in this category. This valuable insight suggests the company should prioritize strategies to retain these loyal customers.

# %%
from scipy.stats import norm

# Extracting the mean and standard deviation for the "MntFruits" variable
mean_fruits = sm_df["MntFruits"].mean()
std_dev_fruits = sm_df["MntFruits"].std()

print(f"Estimated Mean of fruit products: {mean_fruits}")
print(f"Estimated Standard Deviation of fruit products: {std_dev_fruits}")

# Generating some data points for the x-axis
x_fruits = np.linspace(mean_fruits - 3*std_dev_fruits, mean_fruits + 3*std_dev_fruits, 100)

# Calculating the corresponding y-axis values using the normal distribution
y_fruits = norm.pdf(x_fruits, mean_fruits, std_dev_fruits)

# Plotting the continuous normal distribution
plt.plot(x_fruits, y_fruits, label='Normal Distribution')
plt.title('Continuous Normal Distribution of Fruits')
plt.xlabel('Amount Spent on Fruits')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean of fruit products: 26.356046931407942
# Estimated Standard Deviation of fruit products: 39.793916518238696

# %% [markdown]
# **Conclusion**: Examining the normal distribution of fruit sales reveals a key finding: customers typically spend around 30 unit money on fruit products. This valuable customer behavior data presents the company with a strategic opportunity to enhance fruit sales. By implementing targeted strategies, the company can encourage increased spending in this category.

# %%
from scipy.stats import norm

# Extracting the mean and standard deviation for the "MntSweetProducts" spending category
mean_sweet = sm_df['MntSweetProducts'].mean()
std_dev_sweet = sm_df['MntSweetProducts'].std()

print(f"Estimated Mean Number of Sweet products: {mean_sweet}")
print(f"Estimated Standard Deviation of Sweet products: {std_dev_sweet}")
# Generating some data points for the x-axis
x_sweet = np.linspace(mean_sweet - 3*std_dev_sweet, mean_sweet + 3*std_dev_sweet, 100)

# Calculating the corresponding y-axis values using the normal distribution
y_sweet = norm.pdf(x_sweet, mean_sweet, std_dev_sweet)

# Plotting the continuous normal distribution for "MntSweetProducts"
plt.plot(x_sweet, y_sweet, label='Normal Distribution')
plt.title('Continuous Normal Distribution of Sweet Products')
plt.xlabel('Spending Amount')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean Number of Sweet products: 27.028880866425993
# Estimated Standard Deviation of Sweet products: 41.07204566698227

# %% [markdown]
# **Conclusion**: Analyzing the normal distribution of sweet product spending reveals an interesting trend: customers typically spend around 27 unit money on these products. This valuable customer insight presents the company with an opportunity to unlock further sales potential in the sweet product category. By developing innovative marketing strategies or introducing new product lines, the company can encourage increased spending and customer satisfaction.

# %%
# Extracting the mean and standard deviation for the "wine Products" spending category
mean_wines = sm_df['MntWines'].mean()
std_dev_wines = sm_df['MntWines'].std()

print(f"Estimated Mean of Wines: {mean_wines}")
print(f"Estimated Standard Deviation of Wines: {std_dev_wines}")
# Generating some data points for the x-axis
x_wines = np.linspace(mean_wines - 3*std_dev_wines, mean_wines + 3*std_dev_wines, 100)

# Calculating the corresponding y-axis values using the normal distribution
y_wines = norm.pdf(x_wines, mean_wines, std_dev_wines)

# Plotting the continuous normal distribution for "MntSweetProducts"
plt.plot(x_wines, y_wines, label='Normal Distribution')
plt.title('Continuous Normal Distribution of Wines')
plt.xlabel('Spending Amount')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean of Wines: 305.09160649819495
# Estimated Standard Deviation of Wines: 337.32792011667175

# %% [markdown]
# **Conclusion**: An analysis of the wine category's normal distribution reveals a compelling insight: customers typically spend around 300 unit money on wines, the highest spending amount across all categories. This signifies a strong sales performance for wines. However, this valuable data also presents the company with an exciting opportunity to further boost sales. By implementing strategic initiatives, the company can focus on retaining these high-spending customers while exploring avenues to encourage even greater spending in the wine category.

# %%
# Extracting the mean and standard deviation for the "Gold Products" spending category
mean_gold = sm_df['MntGoldProds'].mean()
std_dev_gold = sm_df['MntGoldProds'].std()

print(f"Estimated Mean of Gold products: {mean_gold}")
print(f"Estimated Standard Deviation of Gold Products: {std_dev_gold}")

# Generating some data points for the x-axis
x_gold = np.linspace(mean_gold - 3*std_dev_gold, mean_gold + 3*std_dev_gold, 100)

# Calculating the corresponding y-axis values using the normal distribution
y_gold = norm.pdf(x_gold, mean_gold, std_dev_gold)

# Plotting the continuous normal distribution for "MntSweetProducts"
plt.plot(x_gold, y_gold, label='Normal Distribution')
plt.title('Continuous Normal Distribution of Gold Products')
plt.xlabel('Spending Amount')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# Estimated Mean of Gold products: 43.96525270758123
# Estimated Standard Deviation of Gold Products: 51.815414374473676

# %% [markdown]
# **Conclusion:** Examining the normal distribution of gold product spending reveals an interesting data point: customers typically spend around 40 unit money on these products. While this spending might seem moderate, it also suggests significant untapped potential in the gold product category. The company can leverage this customer insight to develop strategic initiatives that unlock the full sales potential of this category.

# %% [markdown]
# # **K-Means Clustering**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans


# Selecting relevant features (numerical for KMeans initially)
features = ['Year_Birth', 'MntFishProducts', 'MntMeatProducts', 'MntFruits',
            'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases',
            'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases']

# Standardizing features (optional but recommended for KMeans)
scaler = StandardScaler()
scaled_features = scaler.fit_transform(sm_df[features])

# Elbow method to determine optimal number of clusters (potentially)
inertias = []
for k in range(1, 11):
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(scaled_features)
  inertias.append(kmeans.inertia_)

# Plotting elbow method to visualize (optional)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), inertias, '-o')
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %% [markdown]
# As it is not very clear from the elbow method that which value of K to choose.We have to find silhouette score to determine optimal numbers of clusters.

# %% [markdown]
# **Silhouette score**

# %%
#Data imputation
imputer = SimpleImputer(strategy='mean')
sm_df_imputed = imputer.fit_transform(sm_df)

# Calculate silhouette scores for each cluster
silhouette_scores = []
for i in range(2, 10):
    kmeans = KMeans(n_clusters=i, random_state=42)
    cluster_labels = kmeans.fit_predict(sm_df_imputed)
    silhouette_scores.append(silhouette_score(sm_df_imputed, cluster_labels))

# Plot the silhouette scores
plt.bar(range(2, 10), silhouette_scores)
plt.xlabel('Number of clusters', fontsize=20)
plt.ylabel('Silhouette Score', fontsize=20)
plt.show()

# %%
sc=max(silhouette_scores)
number_of_clusters=silhouette_scores.index(sc)+2
print("Number of Cluster Required is : ", number_of_clusters)
# Out:
# Number of Cluster Required is :  2

# %%
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Impute missing values
imputer = SimpleImputer(strategy='mean')
sm_df_imputed = pd.DataFrame(imputer.fit_transform(sm_df))

# Scale the data
scaler = StandardScaler()
sm_df_scaled = pd.DataFrame(scaler.fit_transform(sm_df_imputed))

# Apply KMeans
number_of_clusters = 2
kmeans = KMeans(n_clusters=number_of_clusters, random_state=42).fit(sm_df_scaled)
pred = kmeans.predict(sm_df_scaled)

# Add cluster information to the dataframe
sm_df['cluster'] = pred + 1

# %% [markdown]
# To gain deeper customer insights, we've implemented a clustering technique, resulting in a new column named "Cluster." This column effectively segments the data into two distinct groups, categorized as "first" and "second."

# %%
sm_df.head()
# Out:
#       Id  Year_Birth  Education  Marital_Status   Income  Kidhome  Teenhome  \
# 2  10476        1958        NaN             NaN  67267.0        0         1
# 3   1386        1967        NaN             NaN  32474.0        1         1
# 7   1991        1967        NaN             NaN  44931.0        0         1
# 8   4047        1954        NaN             NaN  65324.0        0         1
# 9   9477        1954        NaN             NaN  65324.0        0         1
#
#    Dt_Customer  Recency  MntWines  ...  NumDealsPurchases  NumWebPurchases  \
# 2          NaN        0       134  ...                  1                3
# 3          NaN        0        10  ...                  1                1
# 7          NaN        0        78  ...                  1                2
# 8          NaN        0       384  ...                  3                6
# 9          NaN        0       384  ...                  3                6
#
# ...

# %%
sm_df['cluster'].value_counts()
# Out:
# cluster
# 1    892
# 2    444
# Name: count, dtype: int64

# %%
pl = sns.countplot(x=sm_df["cluster"])
pl.set_title("Distribution Of The Clusters")
plt.show()

# %% [markdown]
# Cluster 1 contains information of 892 customers while Cluster 2 contains information of 444 customers.

# %%
# Setting the background and grid colors
sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'black', 'axes.grid' : False})

# Listing of columns to exclude
exclude_columns = ["Id", "Education", "Marital_Status", "Dt_Customer", "cluster"]

# Looping through the features to create histograms
for i in sm_df.columns:
    if i not in exclude_columns:
        diag = sns.FacetGrid(sm_df, col="cluster", hue="cluster", palette="Set1", col_wrap=4)
        diag.map(sns.histplot, i, bins=6, ec="k")
        diag.set_xticklabels(rotation=25, color='white')
        diag.set_yticklabels(color='white')
        diag.set_xlabels(size=16, color='white')
        diag.set_ylabels(size=16, color='white')
        diag.set_titles(size=16, color='#f01132', fontweight="bold")
        diag.fig.set_figheight(6)
        diag.fig.set_figwidth(10)

plt.show()

# %% [markdown]
# **Observations**:  Based on above information we can divide customer into 2 parts:
#
# Highly Active Customer :- These customers belong to cluster one.
#
# Least Active Customer :- These customers belong to cluster two.
#
# 1.Characteristics of Highly Active Customer:
#
# (a)In terms of Education:
# Highly Active Customer are from PG background
#
# (b)In terms of Marital_status:
# Number of people in relationship are approx. two times of single people
#
# (c)In terms of Income:
# Income of Highly active customer are little less as compare to least active customer.
#
# (d)In terms of Kids:
# Highly active customer have more number of children as compare to other customer ( avg. of 1 child ).
#
# (e)In terms of Expenses:
# Expenses of Highly Active customer are less as compare to least. These customer spent avg. of approx. 100-200 unit money.
#
# 2.Characteristics of Least Active Customer:
#
# (a)In terms of Education:
# Least Active Customer are from UG backgroud
#
# (b)In terms of Marital_status:
# Number of people in relationship are approx. equal to single people
#
# (c)In terms of Income:
# Income of Least active customer are very less or say negligible.
#
# (d)In terms of Kids:
# Only few of these customer have child.
#
# (e)In terms of Expenses:
# Expenses of Least Active customer are very less or say negligible.
#
# (f)In terms of Age:
# Age of these customer are between 15-30.
#
# (g)In terms of day_engaged:
# Least Active customer are not much enrolled with company for longer time

# %% [markdown]
# # **Conclusion:**

# %% [markdown]
# Project Overview:
#
# This project involved analyzing customer data provided by a company to gain valuable insights that can be used to optimize sales strategies. The dataset contained 2240 rows and 22 columns, encompassing a rich variety of customer demographics (date of birth, education level, marital status, number of children) and financial information (income, expenses). Additionally, it included sales data for various product categories (wines, fruits, gold products, fish products, meat products) over a two-year period.
#
# **1.Data Preparation:**
#
# (a)Data Loading: The initial step involved mounting the dataset from Google Drive, making it accessible for analysis.
# (b)Data Cleaning: To ensure data quality, duplicate entries and rows with missing purchase amounts were meticulously removed.
#
# **2.Data Exploration and Analysis:**
#
# (a)Exploratory Data Analysis (EDA): A comprehensive EDA was performed on the cleansed data to uncover hidden patterns, trends, and relationships between variables. This in-depth exploration provided a foundational understanding of the customer base and their purchasing behaviors.
#
# (b)Descriptive Statistics: Key variables were analyzed using descriptive statistics, calculating measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation). These statistics provided a clear picture of how the data is distributed and summarized the customer characteristics.
#
# (c)Probability Distributions: Specific probability distributions were identified for relevant variables. Bernoulli distributions were used to model customer responses to offers and complaints. Poisson distributions were employed for analyzing purchase frequencies (number of online purchases, number of deal purchases etc.). Nominal probability distributions were applied to understand spending patterns across categories like wines, gold products, meat products and so on.
#
# (d)Customer Segmentation: Clustering techniques were implemented to segment customers into two distinct clusters based on their purchase activity levels. This segmentation allowed for targeted analysis and the identification of groups with high and low purchase frequency.
#
# **Expected Outcome**:
#
# Through the comprehensive analyses conducted in this project, the company is expected to gain valuable customer insights. By understanding customer demographics, spending habits, and purchase behavior patterns, the company can develop data-driven sales strategies to boost sales and achieve future growth.
